# %% [markdown]
# # ASSIGNMENT DAY 1

# %% [markdown]
# # QUESTION 1

# %% [raw]
# b). RAINBOW

# %% [markdown]
# # QUESTION 2

# %%
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %% [markdown]
# # QUESTION 3

# %%
a = float(input("Cost price \t"))
b = float(input("Selling Price \t"))

if a < b:
    print("Transaction is a Profit")
elif a > b:
    print("Transaction is Loss ")
else:
    print("Transaction is Neither loss nor profit")
# Out:
# Cost price 	100
# Selling Price 	200
# Transaction is a Profit

# %% [markdown]
# # QUESTION 4

# %%
a = int(input())
b = int(input())

if a < b:
    print("Profit")
elif a > b:
    print("Loss")
else:
    print("Neither")
# Out:
# 20
# 30
# Profit

# %% [markdown]
# # QUESTION 5

# %%
print(int(input())*80)
# Out:
# 20
# 1600
